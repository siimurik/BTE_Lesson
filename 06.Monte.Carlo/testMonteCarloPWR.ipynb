# %%
import h5py
import time as t
import numpy as np
import numba as nb
from numba import njit, prange
import matplotlib.pyplot as plt
import montepy as mp

# %%
def hdf2dict(file_name):
    # Define the dictionary to store the datasets
    data = {}
    #file_name = 'macro421_UO2_03__900K.h5'
    with h5py.File("..//02.Macro.XS.421g/" + file_name, "r") as file:
        # Iterate over the dataset names in the group
        for dataset_name in file.keys():
            # Read the dataset
            dataset = file[dataset_name]
            # Check if the dataset is a struct
            if isinstance(dataset, h5py.Group):
                # Create a dictionary to store the struct fields
                struct_data = {}
                # Iterate over the fields in the struct
                for field_name in dataset.keys():
                    # Read the field dataset
                    field_dataset = np.array(dataset[field_name])
                    # Store the field dataset in the struct dictionary
                    struct_data[field_name] = field_dataset
                # Store the struct data in the main data dictionary
                data[dataset_name] = struct_data
            else:
                # Read the dataset as a regular array
                dataset_array = np.array(dataset)
                # Store the dataset array in the dictionary
                data[dataset_name] = dataset_array

#print(data["SigC"])
    return data

#file_name = 'macro421_UO2_03__900K.h5'
#fuelDict = hdf2dict(file_name)
#fuelDict.keys()

# %%
"""
import numpy as np
cimport numpy as np
cimport cython

@cython.boundscheck(False)
@cython.wraparound(False)
def perform_collision(bint virtualCollision, bint absorbed, 
                        np.ndarray[double, ndim=2] SigS, double SigA, double SigP, 
                        np.ndarray[double, ndim=1] SigTmax, 
                        np.ndarray[np.int64_t, ndim=1] iGroup, 
                        int iNeutron, 
                        np.ndarray[double, ndim=1] detectS, 
                        np.ndarray[double, ndim=1] weight, 
                        np.ndarray[double, ndim=1] fuel_chi):
    cdef double SigS_sum = np.sum(SigS)
    # ... total
    cdef double SigT = SigA + SigS_sum
    # ... virtual
    cdef double SigV = SigTmax[iGroup[iNeutron]] - SigT

    # Sample the type of the collision: virtual (do nothing) or real
    if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision

        virtualCollision = True

    else:  # real collision

        virtualCollision = False

    # Sample type of the collision: scattering or absorption
    if SigS_sum / SigT >= np.random.rand():  # isotropic scattering

        # Score scatterings with account for weight divided by the
        # total scattering cross section
        detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum

        # Sample the energy group of the secondary neutron
        iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())

    else:  # absorption

        absorbed = True

        # Neutron is converted to the new fission neutron with
        # the weight increased by eta
        weight[iNeutron] *= SigP / SigA

        # Sample the energy group for the new-born neutron
        iGroup[iNeutron] = np.argmax(np.cumsum(fuel_chi) >= np.random.rand())

    return absorbed, virtualCollision, iGroup, weight, detectS
"""
# Out:
# '\nimport numpy as np\ncimport numpy as np\ncimport cython\n\n@cython.boundscheck(False)\n@cython.wraparound(False)\ndef perform_collision(bint virtualCollision, bint absorbed, \n                        np.ndarray[double, ndim=2] SigS, double SigA, double SigP, \n                        np.ndarray[double, ndim=1] SigTmax, \n                        np.ndarray[np.int64_t, ndim=1] iGroup, \n                        int iNeutron, \n                        np.ndarray[double, ndim=1] detectS, \n                        np.ndarray[double, ndim=1] weight, \n                        np.ndarray[double, ndim=1] fuel_chi):\n    cdef double SigS_sum = np.sum(SigS)\n    # ... total\n    cdef double SigT = SigA + SigS_sum\n    # ... virtual\n    cdef double SigV = SigTmax[iGroup[iNeutron]] - SigT\n\n    # Sample the type of the collision: virtual (do nothing) or real\n    if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision\n\n        virtualCollision = True\n\n    else:  # real collision\n\n        virtualCollision = False\n\n    # Sample type of the collision: scattering or absorption\n    if SigS_sum / SigT >= np.random.rand():  # isotropic scattering\n\n        # Score scatterings with account for weight divided by the\n        # total scattering cross section\n        detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum\n\n        # Sample the energy group of the secondary neutron\n        iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())\n\n    else:  # absorption\n\n        absorbed = True\n\n        # Neutron is converted to the new fission neutron with\n        # the weight increased by eta\n        weight[iNeutron] *= SigP / SigA\n\n        # Sample the energy group for the new-born neutron\n        iGroup[iNeutron] = np.argmax(np.cumsum(fuel_chi) >= np.random.rand())\n\n    return absorbed, virtualCollision, iGroup, weight, detectS\n'

# %%
"""import sample_direction
import move_neutron
import russian_roulette
import split_neutrons
import calculate_keff_cycle
import update_indices
import perform_collision

#def main():
# Start the timer
start_time = t.time()

#--------------------------------------------------------------------------
# Number of source neutrons
numNeutrons_born = 100      # INPUT

# Number of inactive source cycles to skip before starting k-eff accumulation
numCycles_inactive = 100    # INPUT

# Number of active source cycles for k-eff accumulation
numCycles_active = 2000     # INPUT

# Size of the square unit cell
pitch = 3.6  # cm           # INPUT

#--------------------------------------------------------------------------
# Path to macroscopic cross section data:
# (Assuming the corresponding data files are available and accessible)
#macro_xs_path = '..//02.Macro.XS.421g'

# Fill the structures fuel, clad, and cool with the cross-section data
fuel = hdf2dict('macro421_UO2_03__900K.h5')  # INPUT
print(f"File 'macro421_UO2_03__900K.h5' has been read in.")
clad = hdf2dict('macro421_Zry__600K.h5')     # INPUT
print(f"File 'macro421_Zry__600K.h5' has been read in.")
cool  = hdf2dict('macro421_H2OB__600K.h5')   # INPUT
print(f"File 'macro421_H2OB__600K.h5' has been read in.")

# Define the majorant: the maximum total cross-section vector
SigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)

# Number of energy groups
ng = fuel['ng']

#--------------------------------------------------------------------------
# Detectors
detectS = np.zeros(ng)

#--------------------------------------------------------------------------
# Four main vectors describing the neutrons in a batch
x = np.zeros(numNeutrons_born * 2)
y = np.zeros(numNeutrons_born * 2)
weight = np.ones(numNeutrons_born * 2)
iGroup = np.ones(numNeutrons_born * 2, dtype=int)

#--------------------------------------------------------------------------
# Neutrons are assumed born randomly distributed in the cell with weight 1
# with sampled fission energy spectrum
numNeutrons = numNeutrons_born
for iNeutron in range(numNeutrons):
    x[iNeutron] = np.random.rand() * pitch
    y[iNeutron] = np.random.rand() * pitch
    weight[iNeutron] = 1
    # Sample the neutron energy group
    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand()) - 1
    #print(f"iNeutron: {iNeutron}, iGroup[iNeutron]: {iGroup[iNeutron]}")

#--------------------------------------------------------------------------
# Prepare vectors for keff and standard deviation of keff
keff_expected = np.ones(numCycles_active)
sigma_keff = np.zeros(numCycles_active)
keff_active_cycle = np.ones(numCycles_active)
virtualCollision = False

# Main (power) iteration loop
for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

    # Normalize the weights of the neutrons to make the total weight equal to
    # numNeutrons_born (equivalent to division by keff_cycle)
    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
    weight0 = weight.copy()
    #----------------------------------------------------------------------
    # Loop over neutrons
    for iNeutron in range(numNeutrons):

        absorbed = False

        #------------------------------------------------------------------
        # Neutron random walk cycle: from emission to absorption

        while not absorbed:

            # Sample free path length according to the Woodcock method
            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print(freePath)

            if not virtualCollision:
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                dirX, dirY = sample_direction.sample_direction()
            # Fly
            x, y = move_neutron.move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)

            # Find the total and scattering cross sections
            if 0.9 < x[iNeutron] < 2.7:  # INPUT
                SigA = fuel['SigF'][iGroup[iNeutron]] + fuel['SigC'][iGroup[iNeutron]] + fuel['SigL'][iGroup[iNeutron]]
                SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = fuel['SigP'][0, iGroup[iNeutron]]
            elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT
                SigA = cool['SigC'][iGroup[iNeutron]] + cool['SigL'][iGroup[iNeutron]]
                SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0
            else:
                SigA = clad['SigC'][iGroup[iNeutron]] + clad['SigL'][iGroup[iNeutron]]
                SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0
            
            ## Find the other cross sections ...
            ## ... scattering
            #SigS_sum = np.sum(SigS)
            ## ... total
            #SigT = SigA + SigS_sum
            ## ... virtual
            #SigV = SigTmax[iGroup[iNeutron]] - SigT
#
            ## Sample the type of the collision: virtual (do nothing) or real
            #if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision
#
            #    virtualCollision = True
#
            #else:  # real collision
#
            #    virtualCollision = False
#
            #    # Sample type of the collision: scattering or absorption
            #    if SigS_sum / SigT >= np.random.rand():  # isotropic scattering
#
            #        # Score scatterings with account for weight divided by the
            #        # total scattering cross section
            #        detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum
#
            #        # Sample the energy group of the secondary neutron
            #        iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())
#
            #    else:  # absorption
#
            #        absorbed = True
#
            #        # Neutron is converted to the new fission neutron with
            #        # the weight increased by eta
            #        weight[iNeutron] *= SigP / SigA
#
            #        # Sample the energy group for the new-born neutron
            #        iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())
            #absorbed, virtualCollision, iGroup, weight, detectS = perform_collisionNEW(virtualCollision, absorbed, SigS, SigA, SigP, SigTmax, iGroup, iNeutron, detectS, weight, fuel["chi"])
            # Reshape SigS to 1-dimensional array
            #SigS = SigS.flatten()
#
            absorbed, virtualCollision, iGroup, weight, detectS = perform_collision.perform_collision(virtualCollision, absorbed, SigS, SigA, SigP, SigTmax, iGroup, iNeutron, detectS, weight, fuel["chi"])

        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    weight = russian_roulette.russian_roulette(weight, weight0)

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons    
    # Convert x and y to NumPy arrays
    x = np.array(x)
    y = np.array(y)
    x, y, iGroup, weight, numNeutrons = update_indices.update_indices(x, y, iGroup, weight)

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    weight, numNeutrons, x, y, iGroup = split_neutrons.split_neutrons(weight, numNeutrons, x, y, iGroup)

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    calculate_keff_cycle.calculate_keff_cycle(iCycle, numCycles_inactive, numCycles_active, weight, weight0, 
                                              numNeutrons, keff_active_cycle, keff_expected, sigma_keff)

    # End of main (power) iteration


# Calculate the elapsed time
elapsed_time = t.time() - start_time

# Create a new HDF5 file
with h5py.File('resultsPWR.h5', 'w') as hdf:
    # Make a header for the file to be created with important parameters
    header = [
            '---------------------------------------------------------',
            'Python-based Open-source Reactor Physics Education System',
            '---------------------------------------------------------',
            '',
            'function s = resultsPWR',
            '% Results for 2D neutron transport calculation in the PWR-like unit cell using method of Monte Carlo',
            f' Number of source neutrons per k-eff cycle is {numNeutrons_born}',
            f' Number of inactive source cycles to skip before starting k-eff accumulation {numCycles_inactive}',
            f' Number of active source cycles for k-eff accumulation {numCycles_active}'
        ]

    # Write the header as attributes of the root group
    for i, line in enumerate(header):
        hdf.attrs[f'header{i}'] = line

    time = hdf.create_group("time")
    time.create_dataset("elapsedTime_(s)", data = elapsed_time)
    time.create_dataset("elapsedTime_(min)", data = elapsed_time/60)
    time.create_dataset("elapsedTime_(hrs)", data = elapsed_time/3600)

    hdf.create_dataset("keff_expected", data = keff_expected[-1])
    hdf.create_dataset("sigma", data = sigma_keff[-1])
    hdf.create_dataset("keffHistory", data = keff_expected)
    hdf.create_dataset("keffError", data = sigma_keff)

    hdf.create_dataset("eg", data = (fuel["eg"][0:ng] + fuel["eg"][1:ng+1]) / 2)

    # Calculate du and flux_du
    du = np.log(fuel["eg"][1:ng+1] / fuel["eg"][:-1])
    flux_du = detectS / du
    hdf.create_dataset("flux", data = flux_du)
    

# Plot the k-effective
plt.figure()
plt.plot(keff_expected, '-r', label='k_eff')
plt.plot(keff_expected + sigma_keff, '--b', label='k_eff +/- sigma')
plt.plot(keff_expected - sigma_keff, '--b')
plt.grid(True)
plt.xlabel('Iteration number')
plt.ylabel('k-effective')
plt.legend()
plt.tight_layout()
plt.savefig('MC_01_keff.pdf')

# Plot the spectrum
plt.figure()
plt.semilogx((fuel["eg"][0:ng] + fuel["eg"][1:ng+1]) / 2, flux_du)
plt.grid(True)
plt.xlabel('Energy, eV')
plt.ylabel('Neutron flux per unit lethargy, a.u.')
plt.tight_layout()
plt.savefig('MC_02_flux_lethargy.pdf')

    # End of function
"""
# Out:
# 'import sample_direction\nimport move_neutron\nimport russian_roulette\nimport split_neutrons\nimport calculate_keff_cycle\nimport update_indices\nimport perform_collision\n\n#def main():\n# Start the timer\nstart_time = t.time()\n\n#--------------------------------------------------------------------------\n# Number of source neutrons\nnumNeutrons_born = 100      # INPUT\n\n# Number of inactive source cycles to skip before starting k-eff accumulation\nnumCycles_inactive = 100    # INPUT\n\n# Number of active source cycles for k-eff accumulation\nnumCycles_active = 2000     # INPUT\n\n# Size of the square unit cell\npitch = 3.6  # cm           # INPUT\n\n#--------------------------------------------------------------------------\n# Path to macroscopic cross section data:\n# (Assuming the corresponding data files are available and accessible)\n#macro_xs_path = \'..//02.Macro.XS.421g\'\n\n# Fill the structures fuel, clad, and cool with the cross-section data\nfuel = hdf2dict(\'macro421_UO2_03__900K.h5\')  # INPUT\nprint(f"File \'macro421_UO2_03__900K.h5\' has been read in.")\nclad = hdf2dict(\'macro421_Zry__600K.h5\')     # INPUT\nprint(f"File \'macro421_Zry__600K.h5\' has been read in.")\ncool  = hdf2dict(\'macro421_H2OB__600K.h5\')   # INPUT\nprint(f"File \'macro421_H2OB__600K.h5\' has been read in.")\n\n# Define the majorant: the maximum total cross-section vector\nSigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)\n\n# Number of energy groups\nng = fuel[\'ng\']\n\n#--------------------------------------------------------------------------\n# Detectors\ndetectS = np.zeros(ng)\n\n#--------------------------------------------------------------------------\n# Four main vectors describing the neutrons in a batch\nx = np.zeros(numNeutrons_born * 2)\ny = np.zeros(numNeutrons_born * 2)\nweight = np.ones(numNeutrons_born * 2)\niGroup = np.ones(numNeutrons_born * 2, dtype=int)\n\n#--------------------------------------------------------------------------\n# Neutrons are assumed born randomly distributed in the cell with weight 1\n# with sampled fission energy spectrum\nnumNeutrons = numNeutrons_born\nfor iNeutron in range(numNeutrons):\n    x[iNeutron] = np.random.rand() * pitch\n    y[iNeutron] = np.random.rand() * pitch\n    weight[iNeutron] = 1\n    # Sample the neutron energy group\n    iGroup[iNeutron] = np.argmax(np.cumsum(fuel[\'chi\']) >= np.random.rand()) - 1\n    #print(f"iNeutron: {iNeutron}, iGroup[iNeutron]: {iGroup[iNeutron]}")\n\n#--------------------------------------------------------------------------\n# Prepare vectors for keff and standard deviation of keff\nkeff_expected = np.ones(numCycles_active)\nsigma_keff = np.zeros(numCycles_active)\nkeff_active_cycle = np.ones(numCycles_active)\nvirtualCollision = False\n\n# Main (power) iteration loop\nfor iCycle in range(1, numCycles_inactive + numCycles_active + 1):\n\n    # Normalize the weights of the neutrons to make the total weight equal to\n    # numNeutrons_born (equivalent to division by keff_cycle)\n    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\n    weight0 = weight.copy()\n    #----------------------------------------------------------------------\n    # Loop over neutrons\n    for iNeutron in range(numNeutrons):\n\n        absorbed = False\n\n        #------------------------------------------------------------------\n        # Neutron random walk cycle: from emission to absorption\n\n        while not absorbed:\n\n            # Sample free path length according to the Woodcock method\n            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\n            #print(freePath)\n\n            if not virtualCollision:\n                # Sample the direction of neutron flight assuming both\n                # fission and scattering are isotropic in the lab (a strong\n                # assumption!)\n                dirX, dirY = sample_direction.sample_direction()\n            # Fly\n      ...

# %%
def hdf2tuple(file_name):
    data = ()
    with h5py.File("..//02.Macro.XS.421g/" + file_name, "r") as file:
        for dataset_name in file.keys():
            dataset = file[dataset_name]
            if isinstance(dataset, h5py.Group):
                struct_data = ()
                for field_name in dataset.keys():
                    field_dataset = np.array(dataset[field_name])
                    if field_name == "sparse_Sig2":
                        struct_data += tuple(field_dataset)
                    else:
                        struct_data += (field_dataset,)
                data += (struct_data,)
            else:
                dataset_array = np.array(dataset)
                data += (dataset_array,)
    return data

#file_name = 'macro421_UO2_03__900K.h5'
#fuelTuple = hdf2tuple('macro421_UO2_03__900K.h5')
# Step 1: fuel SigF, SigC and SigL 
#fuelDict["SigF"] == fuelTuple[1]
#fuelDict["SigC"][99] == fuelTuple[0][99]
#fuelDict["SigL"] == fuelTuple[2]
#fuelDict["sigS_G"]["sparse_SigS[0]"] == fuelTuple[-2][-2]
#fuelTuple[-2][-2][0,0]
#fuelDict['SigP'] == fuelTuple[3] Furthermore: #fuelDict['SigP'][0, 99] == fuelTuple[3][0, 99]
#coolDict['SigC'] == coolTuple[0]
#coolDict['SigL'] == coolTuple[2]
#coolDict["sigS_G"]["sparse_SigS[0]"] == coolTuple[-2][-3]

#cladDict['SigC'] == cladTuple[0]
#cladDict['SigL'] == cladTuple[2]
#cladDict["sigS_G"]["sparse_SigS[0]"] == cladTuple[-2][-3]
#fuelTuple[6]

# %%
# Start stopwatch
start_time = t.time()  # Placeholder for stopwatch functionality in Python

#--------------------------------------------------------------------------
# Number of source neutrons
numNeutrons_born = 100      # INPUT

# Number of inactive source cycles to skip before starting k-eff accumulation
numCycles_inactive = 100    # INPUT

# Number of active source cycles for k-eff accumulation
numCycles_active = 2     # INPUT

# Size of the square unit cell
pitch = 3.6  # cm           # INPUT

# Define fuel and coolant regions
fuelLeft, fuelRight = 0.9, 2.7  # INPUT
coolLeft, coolRight = 0.7, 2.9  # INPUT
#--------------------------------------------------------------------------
# Path to macroscopic cross section data:
# (Assuming the corresponding data files are available and accessible)
macro_xs_path = '..//02.Macro.XS.421g'

# Fill the structures fuel, clad, and cool with the cross-section data
fuel = hdf2dict('macro421_UO2_03__900K.h5')  # INPUT
print(f"File 'macro421_UO2_03__900K.h5' has been read in.")
clad = hdf2dict('macro421_Zry__600K.h5')     # INPUT
print(f"File 'macro421_Zry__600K.h5' has been read in.")
cool  = hdf2dict('macro421_H2OB__600K.h5')   # INPUT
print(f"File 'macro421_H2OB__600K.h5' has been read in.")

# Define the majorant: the maximum total cross-section vector
# This part just looks at all the three different vectors and creates a new
# vector that picks out the largest value for every index from each of the 
# three vectros. Althought there are some rounding differences.
SigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)

# Number of energy groups
ng = fuel['ng']

#--------------------------------------------------------------------------
# Detectors
detectS = np.zeros(ng)

#--------------------------------------------------------------------------
# Four main vectors describing the neutrons in a batch
x = np.zeros(numNeutrons_born * 2)
y = np.zeros(numNeutrons_born * 2)
weight = np.ones(numNeutrons_born * 2)
iGroup = np.ones(numNeutrons_born * 2, dtype=int)

#--------------------------------------------------------------------------
# Neutrons are assumed born randomly distributed in the cell with weight 1
# with sampled fission energy spectrum
numNeutrons = numNeutrons_born
#np.random.seed(42)  # Set the seed to 42
for iNeutron in range(numNeutrons):
    x[iNeutron] = np.random.rand() * pitch
    y[iNeutron] = np.random.rand() * pitch
    weight[iNeutron] = 1
    # Sample the neutron energy group
    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())
#print(iGroup)

#--------------------------------------------------------------------------
# Prepare vectors for keff and standard deviation of keff
keff_expected = np.ones(numCycles_active)
sigma_keff = np.zeros(numCycles_active)
keff_active_cycle = np.ones(numCycles_active)
virtualCollision = False

#fuelTuple = hdf2tuple('macro421_UO2_03__900K.h5')
#cladTuple = hdf2tuple('macro421_Zry__600K.h5')     # INPUT
#coolTuple = hdf2tuple('macro421_H2OB__600K.h5')   # INPUT
# Out:
# File 'macro421_UO2_03__900K.h5' has been read in.
# File 'macro421_Zry__600K.h5' has been read in.
# File 'macro421_H2OB__600K.h5' has been read in.

# %%
@nb.njit
def sample_direction():
    teta = np.pi * np.random.rand()
    phi = 2.0 * np.pi * np.random.rand()
    dirX = np.sin(teta) * np.cos(phi)
    dirY = np.sin(teta) * np.sin(phi)
    return dirX, dirY

#sample_direction()

# %%
@nb.njit
def move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY):
    x[iNeutron] += freePath * dirX
    y[iNeutron] += freePath * dirY

    # If outside the cell, find the corresponding point inside the cell
    while x[iNeutron] < 0:
        x[iNeutron] += pitch
    while y[iNeutron] < 0:
        y[iNeutron] += pitch
    while x[iNeutron] > pitch:
        x[iNeutron] -= pitch
    while y[iNeutron] > pitch:
        y[iNeutron] -= pitch

    return x, y

# %%
@nb.njit
def move_neutronV2(x, y, iNeutron, pitch, freePath, dirX, dirY):
    x[iNeutron] += freePath * dirX
    y[iNeutron] += freePath * dirY

    # Adjust neutron positions to be within the cell boundaries
    x = np.mod(x, pitch)
    y = np.mod(y, pitch)

    return x, y

# %%
"""dirX, dirY = sample_direction()
iNeutron = 1
np.random.seed(42)
freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
a = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY) 
b = move_neutronV2(x, y, iNeutron, pitch, freePath, dirX, dirY)
a[0] == b[0]"""
# Out:
# 'dirX, dirY = sample_direction()\niNeutron = 1\nnp.random.seed(42)\nfreePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\na = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY) \nb = move_neutronV2(x, y, iNeutron, pitch, freePath, dirX, dirY)\na[0] == b[0]'

# %%
def calculate_cross_sections(fuelLeft, fuelRight, coolLeft, coolRight, x, iNeutron, iGroup, fuel, cool, clad):
    if fuelLeft < x[iNeutron] < fuelRight:
        SigA = fuel['SigF'][iGroup[iNeutron]] + fuel['SigC'][iGroup[iNeutron]] + fuel['SigL'][iGroup[iNeutron]]
        SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
        SigP = fuel['SigP'][0, iGroup[iNeutron]]
    elif x[iNeutron] < coolLeft or x[iNeutron] > coolRight:
        SigA = cool['SigC'][iGroup[iNeutron]] + cool['SigL'][iGroup[iNeutron]]
        SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
        SigP = 0
    else:
        SigA = clad['SigC'][iGroup[iNeutron]] + clad['SigL'][iGroup[iNeutron]]
        SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
        SigP = 0

    return SigA, SigS, SigP

# %%
def calculate_cross_sectionsV2(fuelLeft, fuelRight, coolLeft, coolRight, x, iNeutron, iGroup, fuel, cool, clad):

    condition1 = (fuelLeft < x) & (x < fuelRight)
    condition2 = (x < coolLeft) | (x > coolRight)

    SigA = 0.0  # Initialize SigA with zeros
    SigP = 0.0
    SigS = np.zeros_like(iGroup)  # Initialize SigA with zeros

    # Update arrays based on conditions
    SigA = np.where(condition1, fuel['SigF'][iGroup] + fuel['SigC'][iGroup] + fuel['SigL'][iGroup], SigA)
    SigA = np.where(condition2, cool['SigC'][iGroup] + cool['SigL'][iGroup], SigA)
    SigA = np.where(~(condition1 | condition2), clad['SigC'][iGroup] + clad['SigL'][iGroup], SigA)

    SigS = np.where(condition1, fuel["sigS_G"]["sparse_SigS[0]"][iGroup, :].reshape(-1, 1), SigS)
    SigS = np.where(condition2, cool["sigS_G"]["sparse_SigS[0]"][iGroup, :].reshape(-1, 1), SigS)
    SigS = np.where(~(condition1 | condition2), clad["sigS_G"]["sparse_SigS[0]"][iGroup, :].reshape(-1, 1), SigS)

    SigP = np.where(condition1, fuel['SigP'][0, iGroup], SigP)
    SigP = np.where(condition2, 0, SigP)
    
    return SigA, SigS, SigP

# %%
def perform_collision(virtualCollision, absorbed, SigS, SigA, SigP, SigTmax,
                      iGroup, iNeutron, detectS, weight, fuel_chi):
    SigS_sum = np.sum(SigS)
    SigT = SigA + SigS_sum
    SigV = SigTmax[iGroup[iNeutron]] - SigT

    if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():
        virtualCollision = True
    else:
        virtualCollision = False

    if SigS_sum / SigT >= np.random.rand():
        detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum
        iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())
    else:
        absorbed = True
        weight[iNeutron] *= SigP / SigA
        iGroup[iNeutron] = np.argmax(np.cumsum(fuel_chi) >= np.random.rand())

    return absorbed, virtualCollision, iGroup, weight, detectS

# %%
"""@nb.njit
def simulate_collision(SigS, SigA, SigTmax, iGroup, weight, detectS, fuel_SigP, fuel_chi):
    # Find the other cross sections ...
    # ... scattering
    SigS_sum = np.sum(SigS)
    # ... total
    SigT = SigA + SigS_sum
    # ... virtual
    SigV = SigTmax[iGroup] - SigT

    # Sample the type of the collision: virtual (do nothing) or real
    if SigV / SigTmax[iGroup] >= np.random.rand():  # virtual collision
        virtualCollision = True
    else:  # real collision
        virtualCollision = False

        # Sample type of the collision: scattering or absorption
        if SigS_sum / SigT >= np.random.rand():  # isotropic scattering
            # Score scatterings with account for weight divided by the
            # total scattering cross section
            detectS[iGroup] += weight / SigS_sum

            # Sample the energy group of the secondary neutron
            iGroup = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())
        else:  # absorption
            absorbed = True

            # Neutron is converted to the new fission neutron with
            # the weight increased by eta
            weight *= fuel_SigP / SigA

            # Sample the energy group for the new-born neutron
            iGroup = np.argmax(np.cumsum(fuel_chi) >= np.random.rand())

    return virtualCollision, absorbed, iGroup

weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
dirX, dirY = sample_direction()
freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
x, y = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)
# Find the total and scattering cross sections
if 0.9 < x[iNeutron] < 2.7:  # INPUT
    SigA = fuel['SigF'][iGroup[iNeutron]] + fuel['SigC'][iGroup[iNeutron]] + fuel['SigL'][iGroup[iNeutron]]
    SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
    SigP = fuel['SigP'][0, iGroup[iNeutron]]
elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT
    SigA = cool['SigC'][iGroup[iNeutron]] + cool['SigL'][iGroup[iNeutron]]
    SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
    SigP = 0
else:
    SigA = clad['SigC'][iGroup[iNeutron]] + clad['SigL'][iGroup[iNeutron]]
    SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
    SigP = 0

fuel_SigP = fuel["SigP"]
fuel_chi = fuel["chi"]
virtualCollision, absorbed, iGroup = simulate_collision(SigS, SigA, SigTmax, iGroup, weight, detectS, fuel_SigP, fuel_chi)
"""
# Out:
# '@nb.njit\ndef simulate_collision(SigS, SigA, SigTmax, iGroup, weight, detectS, fuel_SigP, fuel_chi):\n    # Find the other cross sections ...\n    # ... scattering\n    SigS_sum = np.sum(SigS)\n    # ... total\n    SigT = SigA + SigS_sum\n    # ... virtual\n    SigV = SigTmax[iGroup] - SigT\n\n    # Sample the type of the collision: virtual (do nothing) or real\n    if SigV / SigTmax[iGroup] >= np.random.rand():  # virtual collision\n        virtualCollision = True\n    else:  # real collision\n        virtualCollision = False\n\n        # Sample type of the collision: scattering or absorption\n        if SigS_sum / SigT >= np.random.rand():  # isotropic scattering\n            # Score scatterings with account for weight divided by the\n            # total scattering cross section\n            detectS[iGroup] += weight / SigS_sum\n\n            # Sample the energy group of the secondary neutron\n            iGroup = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())\n        else:  # absorption\n            absorbed = True\n\n            # Neutron is converted to the new fission neutron with\n            # the weight increased by eta\n            weight *= fuel_SigP / SigA\n\n            # Sample the energy group for the new-born neutron\n            iGroup = np.argmax(np.cumsum(fuel_chi) >= np.random.rand())\n\n    return virtualCollision, absorbed, iGroup\n\nweight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\ndirX, dirY = sample_direction()\nfreePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\nx, y = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)\n# Find the total and scattering cross sections\nif 0.9 < x[iNeutron] < 2.7:  # INPUT\n    SigA = fuel[\'SigF\'][iGroup[iNeutron]] + fuel[\'SigC\'][iGroup[iNeutron]] + fuel[\'SigL\'][iGroup[iNeutron]]\n    SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n    SigP = fuel[\'SigP\'][0, iGroup[iNeutron]]\nelif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT\n    SigA = cool[\'SigC\'][iGroup[iNeutron]] + cool[\'SigL\'][iGroup[iNeutron]]\n    SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n    SigP = 0\nelse:\n    SigA = clad[\'SigC\'][iGroup[iNeutron]] + clad[\'SigL\'][iGroup[iNeutron]]\n    SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n    SigP = 0\n\nfuel_SigP = fuel["SigP"]\nfuel_chi = fuel["chi"]\nvirtualCollision, absorbed, iGroup = simulate_collision(SigS, SigA, SigTmax, iGroup, weight, detectS, fuel_SigP, fuel_chi)\n'

# %%
@nb.njit
def russian_roulette(weight, weight0):
    numNeutrons = len(weight)
    for iNeutron in range(numNeutrons):
        terminateP = 1 - weight[iNeutron] / weight0[iNeutron]
        if terminateP >= np.random.rand():
            weight[iNeutron] = 0  # killed
        elif terminateP > 0:
            weight[iNeutron] = weight0[iNeutron]  # restore the weight
    return weight

# %%
@nb.njit
def split_neutrons(weight, numNeutrons, x, y, iGroup):
    numNew = 0
    for iNeutron in range(numNeutrons):
        if weight[iNeutron] > 1:
            N = int(weight[iNeutron])
            if weight[iNeutron] - N > np.random.rand():
                N += 1
            weight[iNeutron] = weight[iNeutron] / N
            for iNew in range(N - 1):
                numNew += 1
                x = np.append(x, x[iNeutron])
                y = np.append(y, y[iNeutron])
                weight = np.append(weight, weight[iNeutron])
                iGroup = np.append(iGroup, iGroup[iNeutron])
    numNeutrons += numNew
    return weight, numNeutrons, x, y, iGroup

#weight, numNeutrons, x, y, iGroup = split_neutrons(weight, numNeutrons, x, y, iGroup)

# %%
@nb.njit
def split_neutronsV2(weight, numNeutrons, x, y, iGroup):
    numNew = np.sum(weight > 1)
    N = np.floor(weight).astype(int)
    N += (weight - N) > np.random.rand(len(weight))
    weight = weight / N
    numNew = int(np.sum(N - 1))

    x = np.repeat(x, N)
    y = np.repeat(y, N)
    weight = np.repeat(weight, N)
    iGroup = np.repeat(iGroup, N)

    numNeutrons += numNew
    return weight, numNeutrons, x, y, iGroup

# %%
@nb.njit
def update_indices(x, y, iGroup, weight):
    # Get the indices of non-zero weight
    indices = np.nonzero(weight)[0]

    # Perform indexing
    x = x[indices]
    y = y[indices]
    iGroup = iGroup[indices]
    weight = weight[indices]
    
    # Update numNeutrons
    numNeutrons = weight.shape[0]
    
    return x, y, iGroup, weight, numNeutrons

# %%
def calculate_keff_cycle(iCycle, numCycles_inactive, numCycles_active, weight, weight0, numNeutrons,
                         keff_active_cycle, keff_expected, sigma_keff):
    iActive = iCycle - numCycles_inactive
    keff_cycle = np.sum(weight) / np.sum(weight0)

    if iActive <= 0:
        msg = f"Inactive cycle = {iCycle:3d}/{numCycles_inactive:3d}; k-eff cycle = {keff_cycle:.5f}; numNeutrons = {numNeutrons:3d}"
        print(msg)
    else:
        keff_active_cycle[iActive-1] = keff_cycle
        keff_expected[iActive-1] = np.mean(keff_active_cycle[:iActive])
        sigma_keff[iActive-1] = np.sqrt(np.sum((keff_active_cycle[:iActive] - keff_expected[iActive-1]) ** 2) / max(iActive - 1, 1) / iActive)

        msg = f"Active cycle = {iActive:3d}/{numCycles_active:3d}; k-eff cycle = {keff_cycle:.5f}; numNeutrons = {numNeutrons:3d}; k-eff expected = {keff_expected[iActive-1]:.5f}; sigma = {sigma_keff[iActive-1]:.5f}"
        print(msg)

# %%
"""# Main (power) iteration loop
for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

    # Normalize the weights of the neutrons to make the total weight equal to
    # numNeutrons_born (equivalent to division by keff_cycle)
    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
    weight0 = weight.copy()
    #----------------------------------------------------------------------
    # Loop over neutrons
    for iNeutron in range(numNeutrons):

        absorbed = False

        #------------------------------------------------------------------
        # Neutron random walk cycle: from emission to absorption

        while not absorbed:

            # Sample free path length according to the Woodcock method
            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print(freePath)

            if not virtualCollision:
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                dirX, dirY = sample_direction()
            # Fly
            x, y = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)

            # Find the total and scattering cross sections
            if 0.9 < x[iNeutron] < 2.7:  # INPUT
                SigA = fuel['SigF'][iGroup[iNeutron]] + fuel['SigC'][iGroup[iNeutron]] + fuel['SigL'][iGroup[iNeutron]]
                SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = fuel['SigP'][0, iGroup[iNeutron]]
            elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT
                SigA = cool['SigC'][iGroup[iNeutron]] + cool['SigL'][iGroup[iNeutron]]
                SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0
            else:
                SigA = clad['SigC'][iGroup[iNeutron]] + clad['SigL'][iGroup[iNeutron]]
                SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0

            # Find the other cross sections ...
            # ... scattering
            SigS_sum = np.sum(SigS)
            # ... total
            SigT = SigA + SigS_sum
            # ... virtual
            SigV = SigTmax[iGroup[iNeutron]] - SigT

            # Sample the type of the collision: virtual (do nothing) or real
            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision

                virtualCollision = True

            else:  # real collision

                virtualCollision = False

                # Sample type of the collision: scattering or absorption
                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering

                    # Score scatterings with account for weight divided by the
                    # total scattering cross section
                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum

                    # Sample the energy group of the secondary neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())

                else:  # absorption

                    absorbed = True

                    # Neutron is converted to the new fission neutron with
                    # the weight increased by eta
                    weight[iNeutron] *= SigP / SigA

                    # Sample the energy group for the new-born neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())

        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    weight = russian_roulette(weight, weight0)

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons
    indices = np.nonzero(weight)
    x = x[indices]
    y = y[indices]
    iGroup = iGroup[indices]
    weight = weight[indices]
    numNeutrons = weight.shape[0]

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    weight, numNeutrons, x, y, iGroup = split_neutrons(weight, numNeutrons, x, y, iGroup)

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    keff_cycle = np.sum(weight) / np.sum(weight0)

    iActive = iCycle - numCycles_inactive
    if iActive <= 0:
        print('Inactive cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}'.format(
            iCycle, numCycles_inactive, keff_cycle, numNeutrons))
    else:
        print("iActive =", iActive)
        # k-effective of the cycle
        keff_active_cycle[iActive-1] = keff_cycle

        # k-effective of the problem
        keff_expected[iActive-1] = np.mean(keff_active_cycle[:iActive])

        # Standard deviation of k-effective
        sigma_keff[iActive-1] = np.sqrt(
            np.sum((keff_active_cycle[:iActive] - keff_expected[iActive-1]) ** 2) / max(iActive - 1, 1) / iActive)

        print('Active cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}; k-eff expected = {:.5f}; sigma = {:.5f}'.format(
            iCycle - numCycles_inactive, numCycles_active, keff_cycle, numNeutrons, keff_expected[iActive-1], sigma_keff[iActive-1]))

    # End of main (power) iteration
"""
# Out:
# '# Main (power) iteration loop\nfor iCycle in range(1, numCycles_inactive + numCycles_active + 1):\n\n    # Normalize the weights of the neutrons to make the total weight equal to\n    # numNeutrons_born (equivalent to division by keff_cycle)\n    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\n    weight0 = weight.copy()\n    #----------------------------------------------------------------------\n    # Loop over neutrons\n    for iNeutron in range(numNeutrons):\n\n        absorbed = False\n\n        #------------------------------------------------------------------\n        # Neutron random walk cycle: from emission to absorption\n\n        while not absorbed:\n\n            # Sample free path length according to the Woodcock method\n            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\n            #print(freePath)\n\n            if not virtualCollision:\n                # Sample the direction of neutron flight assuming both\n                # fission and scattering are isotropic in the lab (a strong\n                # assumption!)\n                dirX, dirY = sample_direction()\n            # Fly\n            x, y = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)\n\n            # Find the total and scattering cross sections\n            if 0.9 < x[iNeutron] < 2.7:  # INPUT\n                SigA = fuel[\'SigF\'][iGroup[iNeutron]] + fuel[\'SigC\'][iGroup[iNeutron]] + fuel[\'SigL\'][iGroup[iNeutron]]\n                SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = fuel[\'SigP\'][0, iGroup[iNeutron]]\n            elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT\n                SigA = cool[\'SigC\'][iGroup[iNeutron]] + cool[\'SigL\'][iGroup[iNeutron]]\n                SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n            else:\n                SigA = clad[\'SigC\'][iGroup[iNeutron]] + clad[\'SigL\'][iGroup[iNeutron]]\n                SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n\n            # Find the other cross sections ...\n            # ... scattering\n            SigS_sum = np.sum(SigS)\n            # ... total\n            SigT = SigA + SigS_sum\n            # ... virtual\n            SigV = SigTmax[iGroup[iNeutron]] - SigT\n\n            # Sample the type of the collision: virtual (do nothing) or real\n            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision\n\n                virtualCollision = True\n\n            else:  # real collision\n\n                virtualCollision = False\n\n                # Sample type of the collision: scattering or absorption\n                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering\n\n                    # Score scatterings with account for weight divided by the\n                    # total scattering cross section\n                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum\n\n                    # Sample the energy group of the secondary neutron\n                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())\n\n                else:  # absorption\n\n                    absorbed = True\n\n                    # Neutron is converted to the new fission neutron with\n                    # the weight increased by eta\n                    weight[iNeutron] *= SigP / SigA\n\n                    # Sample the energy group for the new-born neutron\n                    iGroup[iNeutron] = np.argmax(np.cumsum(fuel[\'chi\']) >= np.random.rand())\n\n        # End of neutron random walk cycle: from emission to absorption\n    # End of loop over neutrons\n    #-------------------------------------------------------------------------------------------\n    # Russian roulette\n    weight = russian_roulette(weight, weight0)\n\n    #---------------------------------- ...

# %%
"""#@njit
def perform_random_walk(x, y, iGroup, weight, numNeutrons, numNeutrons_born, numCycles_inactive, numCycles_active, virtualCollision):
    # Define other variables and arrays used in the code

    # Main (power) iteration loop
    for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

        # Normalize the weights of the neutrons to make the total weight equal to
        # numNeutrons_born (equivalent to division by keff_cycle)
        weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
        weight0 = weight.copy()

        # Loop over neutrons
        for iNeutron in range(numNeutrons):
            absorbed = False

            # Neutron random walk cycle: from emission to absorption
            while not absorbed:
                # Sample free path length according to the Woodcock method
                freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print(freePath)

            if not virtualCollision:
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                teta = np.pi * np.random.rand()
                phi = 2.0 * np.pi * np.random.rand()
                dirX = np.sin(teta) * np.cos(phi)
                dirY = np.sin(teta) * np.sin(phi)

            # Fly
            x[iNeutron] += freePath * dirX
            y[iNeutron] += freePath * dirY

            # If outside the cell, find the corresponding point inside the
            # cell
            while x[iNeutron] < 0:
                x[iNeutron] += pitch
            while y[iNeutron] < 0:
                y[iNeutron] += pitch
            while x[iNeutron] > pitch:
                x[iNeutron] -= pitch
            while y[iNeutron] > pitch:
                y[iNeutron] -= pitch

            # Find the total and scattering cross sections
            if 0.9 < x[iNeutron] < 2.7:  # INPUT
                SigA = fuelTuple[1][iGroup[iNeutron]] + fuelTuple[0][iGroup[iNeutron]] + fuelTuple[2][iGroup[iNeutron]]
                SigS = fuelTuple[-2][-2][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = fuelTuple[3][0, iGroup[iNeutron]]
            elif x[iNeutron] < 0.7 or x[iNeutron] > 2.9:  # INPUT
                SigA = coolTuple[0][iGroup[iNeutron]] + coolTuple[2][iGroup[iNeutron]]
                SigS = coolTuple[-2][-3][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0
            else:
                SigA = cladTuple[0][iGroup[iNeutron]] + cladTuple[2][iGroup[iNeutron]]
                SigS = cladTuple[-2][-3][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0

            # Find the other cross sections ...
            # ... scattering
            SigS_sum = np.sum(SigS)
            # ... total
            SigT = SigA + SigS_sum
            # ... virtual
            SigV = SigTmax[iGroup[iNeutron]] - SigT

            # Sample the type of the collision: virtual (do nothing) or real
            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision

                virtualCollision = True

            else:  # real collision

                virtualCollision = False

                # Sample type of the collision: scattering or absorption
                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering

                    # Score scatterings with account for weight divided by the
                    # total scattering cross section
                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum

                    # Sample the energy group of the secondary neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())

                else:  # absorption

                    absorbed = True

                    # Neutron is converted to the new fission neutron with
                    # the weight increased by eta
                    weight[iNeutron] *= SigP / SigA

                    # Sample the energy group for the new-born neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(fuelTuple[6]) >= np.random.rand())

        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    for iNeutron in range(numNeutrons):
        terminateP = 1 - weight[iNeutron] / weight0[iNeutron]
        if terminateP >= np.random.rand():
            weight[iNeutron] = 0  # killed
        elif terminateP > 0:
            weight[iNeutron] = weight0[iNeutron]  # restore the weight

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons
    indices = np.nonzero(weight)
    x = x[indices]
    y = y[indices]
    iGroup = iGroup[indices]
    weight = weight[indices]
    numNeutrons = weight.shape[0]

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    numNew = 0
    for iNeutron in range(numNeutrons):
        if weight[iNeutron] > 1:
            # Truncated integer value of the neutron weight
            N = int(np.floor(weight[iNeutron]))
            # Sample the number of split neutrons
            if weight[iNeutron] - N > np.random.rand():
                N += 1
            # Change the weight of the split neutron
            weight[iNeutron] = weight[iNeutron] / N
            # Introduce new neutrons
            for iNew in range(N - 1):
                numNew += 1
                x = np.append(x, x[iNeutron])
                y = np.append(y, y[iNeutron])
                weight = np.append(weight, weight[iNeutron])
                iGroup = np.append(iGroup, iGroup[iNeutron])

    # Increase the number of neutrons
    numNeutrons += numNew

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    keff_cycle = np.sum(weight) / np.sum(weight0)

    iActive = iCycle - numCycles_inactive
    if iActive <= 0:
        print('Inactive cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}'.format(
            iCycle, numCycles_inactive, keff_cycle, numNeutrons))
    else:
        print("iActive =", iActive)
        # k-effective of the cycle
        keff_active_cycle[iActive-1] = keff_cycle

        # k-effective of the problem
        keff_expected[iActive-1] = np.mean(keff_active_cycle[:iActive])

        # Standard deviation of k-effective
        sigma_keff[iActive-1] = np.sqrt(
            np.sum((keff_active_cycle[:iActive] - keff_expected[iActive-1]) ** 2) / max(iActive - 1, 1) / iActive)

        print('Active cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}; k-eff expected = {:.5f}; sigma = {:.5f}'.format(
            iCycle - numCycles_inactive, numCycles_active, keff_cycle, numNeutrons, keff_expected[iActive-1], sigma_keff[iActive-1]))

    # End of main (power) iteration

perform_random_walk(x, y, iGroup, weight, numNeutrons, numNeutrons_born, numCycles_inactive, numCycles_active, virtualCollision)"""
# Out:
# '#@njit\ndef perform_random_walk(x, y, iGroup, weight, numNeutrons, numNeutrons_born, numCycles_inactive, numCycles_active, virtualCollision):\n    # Define other variables and arrays used in the code\n\n    # Main (power) iteration loop\n    for iCycle in range(1, numCycles_inactive + numCycles_active + 1):\n\n        # Normalize the weights of the neutrons to make the total weight equal to\n        # numNeutrons_born (equivalent to division by keff_cycle)\n        weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\n        weight0 = weight.copy()\n\n        # Loop over neutrons\n        for iNeutron in range(numNeutrons):\n            absorbed = False\n\n            # Neutron random walk cycle: from emission to absorption\n            while not absorbed:\n                # Sample free path length according to the Woodcock method\n                freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\n            #print(freePath)\n\n            if not virtualCollision:\n                # Sample the direction of neutron flight assuming both\n                # fission and scattering are isotropic in the lab (a strong\n                # assumption!)\n                teta = np.pi * np.random.rand()\n                phi = 2.0 * np.pi * np.random.rand()\n                dirX = np.sin(teta) * np.cos(phi)\n                dirY = np.sin(teta) * np.sin(phi)\n\n            # Fly\n            x[iNeutron] += freePath * dirX\n            y[iNeutron] += freePath * dirY\n\n            # If outside the cell, find the corresponding point inside the\n            # cell\n            while x[iNeutron] < 0:\n                x[iNeutron] += pitch\n            while y[iNeutron] < 0:\n                y[iNeutron] += pitch\n            while x[iNeutron] > pitch:\n                x[iNeutron] -= pitch\n            while y[iNeutron] > pitch:\n                y[iNeutron] -= pitch\n\n            # Find the total and scattering cross sections\n            if 0.9 < x[iNeutron] < 2.7:  # INPUT\n                SigA = fuelTuple[1][iGroup[iNeutron]] + fuelTuple[0][iGroup[iNeutron]] + fuelTuple[2][iGroup[iNeutron]]\n                SigS = fuelTuple[-2][-2][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = fuelTuple[3][0, iGroup[iNeutron]]\n            elif x[iNeutron] < 0.7 or x[iNeutron] > 2.9:  # INPUT\n                SigA = coolTuple[0][iGroup[iNeutron]] + coolTuple[2][iGroup[iNeutron]]\n                SigS = coolTuple[-2][-3][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n            else:\n                SigA = cladTuple[0][iGroup[iNeutron]] + cladTuple[2][iGroup[iNeutron]]\n                SigS = cladTuple[-2][-3][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n\n            # Find the other cross sections ...\n            # ... scattering\n            SigS_sum = np.sum(SigS)\n            # ... total\n            SigT = SigA + SigS_sum\n            # ... virtual\n            SigV = SigTmax[iGroup[iNeutron]] - SigT\n\n            # Sample the type of the collision: virtual (do nothing) or real\n            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision\n\n                virtualCollision = True\n\n            else:  # real collision\n\n                virtualCollision = False\n\n                # Sample type of the collision: scattering or absorption\n                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering\n\n                    # Score scatterings with account for weight divided by the\n                    # total scattering cross section\n                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum\n\n                    # Sample the energy group of the secondary neutron\n                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())\n\n                else:  # absorption\n\n                    absorbed = True\n\n                    # Neutron is converted to the new fission n ...

# %%
"""np.random.seed(42)  # Set the seed to 42
freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
np.random.seed(42)  # Set the seed to 42
print(np.random.rand())
print(iGroup[iNeutron])
print(SigTmax[iGroup[iNeutron]])
print(freePath)"""
# Out:
# 'np.random.seed(42)  # Set the seed to 42\nfreePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\nnp.random.seed(42)  # Set the seed to 42\nprint(np.random.rand())\nprint(iGroup[iNeutron])\nprint(SigTmax[iGroup[iNeutron]])\nprint(freePath)'

# %% [markdown]
# ### The Default Main iteration loop (no functions)

# %%
"""# Main (power) iteration loop
for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

    # Normalize the weights of the neutrons to make the total weight equal to
    # numNeutrons_born (equivalent to division by keff_cycle)
    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
    weight0 = weight.copy()
    #----------------------------------------------------------------------
    # Loop over neutrons
    for iNeutron in range(numNeutrons):

        absorbed = False

        #------------------------------------------------------------------
        # Neutron random walk cycle: from emission to absorption

        while not absorbed:

            # Sample free path length according to the Woodcock method
            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print(freePath)

            if not virtualCollision:
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                teta = np.pi * np.random.rand()
                phi = 2.0 * np.pi * np.random.rand()
                dirX = np.sin(teta) * np.cos(phi)
                dirY = np.sin(teta) * np.sin(phi)

            # Fly
            x[iNeutron] += freePath * dirX
            y[iNeutron] += freePath * dirY

            # If outside the cell, find the corresponding point inside the
            # cell
            while x[iNeutron] < 0:
                x[iNeutron] += pitch
            while y[iNeutron] < 0:
                y[iNeutron] += pitch
            while x[iNeutron] > pitch:
                x[iNeutron] -= pitch
            while y[iNeutron] > pitch:
                y[iNeutron] -= pitch

            # Find the total and scattering cross sections
            if 0.9 < x[iNeutron] < 2.7:  # INPUT
                SigA = fuel['SigF'][iGroup[iNeutron]] + fuel['SigC'][iGroup[iNeutron]] + fuel['SigL'][iGroup[iNeutron]]
                SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = fuel['SigP'][0, iGroup[iNeutron]]
            elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT
                SigA = cool['SigC'][iGroup[iNeutron]] + cool['SigL'][iGroup[iNeutron]]
                SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0
            else:
                SigA = clad['SigC'][iGroup[iNeutron]] + clad['SigL'][iGroup[iNeutron]]
                SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)
                SigP = 0

            # Find the other cross sections ...
            # ... scattering
            SigS_sum = np.sum(SigS)
            # ... total
            SigT = SigA + SigS_sum
            # ... virtual
            SigV = SigTmax[iGroup[iNeutron]] - SigT

            # Sample the type of the collision: virtual (do nothing) or real
            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision

                virtualCollision = True

            else:  # real collision

                virtualCollision = False

                # Sample type of the collision: scattering or absorption
                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering

                    # Score scatterings with account for weight divided by the
                    # total scattering cross section
                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum

                    # Sample the energy group of the secondary neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())

                else:  # absorption

                    absorbed = True

                    # Neutron is converted to the new fission neutron with
                    # the weight increased by eta
                    weight[iNeutron] *= SigP / SigA

                    # Sample the energy group for the new-born neutron
                    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())

        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    for iNeutron in range(numNeutrons):
        terminateP = 1 - weight[iNeutron] / weight0[iNeutron]
        if terminateP >= np.random.rand():
            weight[iNeutron] = 0  # killed
        elif terminateP > 0:
            weight[iNeutron] = weight0[iNeutron]  # restore the weight

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons
    indices = np.nonzero(weight)
    x = x[indices]
    y = y[indices]
    iGroup = iGroup[indices]
    weight = weight[indices]
    numNeutrons = weight.shape[0]

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    numNew = 0
    for iNeutron in range(numNeutrons):
        if weight[iNeutron] > 1:
            # Truncated integer value of the neutron weight
            N = int(np.floor(weight[iNeutron]))
            # Sample the number of split neutrons
            if weight[iNeutron] - N > np.random.rand():
                N += 1
            # Change the weight of the split neutron
            weight[iNeutron] = weight[iNeutron] / N
            # Introduce new neutrons
            for iNew in range(N - 1):
                numNew += 1
                x = np.append(x, x[iNeutron])
                y = np.append(y, y[iNeutron])
                weight = np.append(weight, weight[iNeutron])
                iGroup = np.append(iGroup, iGroup[iNeutron])

    # Increase the number of neutrons
    numNeutrons += numNew

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    keff_cycle = np.sum(weight) / np.sum(weight0)

    iActive = iCycle - numCycles_inactive
    if iActive <= 0:
        print('Inactive cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}'.format(
            iCycle, numCycles_inactive, keff_cycle, numNeutrons))
    else:
        print("iActive =", iActive)
        # k-effective of the cycle
        keff_active_cycle[iActive-1] = keff_cycle

        # k-effective of the problem
        keff_expected[iActive-1] = np.mean(keff_active_cycle[:iActive])

        # Standard deviation of k-effective
        sigma_keff[iActive-1] = np.sqrt(
            np.sum((keff_active_cycle[:iActive] - keff_expected[iActive-1]) ** 2) / max(iActive - 1, 1) / iActive)

        print('Active cycle = {:3d}/{:3d}; k-eff cycle = {:.5f}; numNeutrons = {:3d}; k-eff expected = {:.5f}; sigma = {:.5f}'.format(
            iCycle - numCycles_inactive, numCycles_active, keff_cycle, numNeutrons, keff_expected[iActive-1], sigma_keff[iActive-1]))

    # End of main (power) iteration
"""
# Out:
# '# Main (power) iteration loop\nfor iCycle in range(1, numCycles_inactive + numCycles_active + 1):\n\n    # Normalize the weights of the neutrons to make the total weight equal to\n    # numNeutrons_born (equivalent to division by keff_cycle)\n    weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\n    weight0 = weight.copy()\n    #----------------------------------------------------------------------\n    # Loop over neutrons\n    for iNeutron in range(numNeutrons):\n\n        absorbed = False\n\n        #------------------------------------------------------------------\n        # Neutron random walk cycle: from emission to absorption\n\n        while not absorbed:\n\n            # Sample free path length according to the Woodcock method\n            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\n            #print(freePath)\n\n            if not virtualCollision:\n                # Sample the direction of neutron flight assuming both\n                # fission and scattering are isotropic in the lab (a strong\n                # assumption!)\n                teta = np.pi * np.random.rand()\n                phi = 2.0 * np.pi * np.random.rand()\n                dirX = np.sin(teta) * np.cos(phi)\n                dirY = np.sin(teta) * np.sin(phi)\n\n            # Fly\n            x[iNeutron] += freePath * dirX\n            y[iNeutron] += freePath * dirY\n\n            # If outside the cell, find the corresponding point inside the\n            # cell\n            while x[iNeutron] < 0:\n                x[iNeutron] += pitch\n            while y[iNeutron] < 0:\n                y[iNeutron] += pitch\n            while x[iNeutron] > pitch:\n                x[iNeutron] -= pitch\n            while y[iNeutron] > pitch:\n                y[iNeutron] -= pitch\n\n            # Find the total and scattering cross sections\n            if 0.9 < x[iNeutron] < 2.7:  # INPUT\n                SigA = fuel[\'SigF\'][iGroup[iNeutron]] + fuel[\'SigC\'][iGroup[iNeutron]] + fuel[\'SigL\'][iGroup[iNeutron]]\n                SigS = fuel["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = fuel[\'SigP\'][0, iGroup[iNeutron]]\n            elif x[iNeutron] < 0.9 or x[iNeutron] > 2.7:  # INPUT\n                SigA = cool[\'SigC\'][iGroup[iNeutron]] + cool[\'SigL\'][iGroup[iNeutron]]\n                SigS = cool["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n            else:\n                SigA = clad[\'SigC\'][iGroup[iNeutron]] + clad[\'SigL\'][iGroup[iNeutron]]\n                SigS = clad["sigS_G"]["sparse_SigS[0]"][iGroup[iNeutron], :].reshape(-1, 1)\n                SigP = 0\n\n            # Find the other cross sections ...\n            # ... scattering\n            SigS_sum = np.sum(SigS)\n            # ... total\n            SigT = SigA + SigS_sum\n            # ... virtual\n            SigV = SigTmax[iGroup[iNeutron]] - SigT\n\n            # Sample the type of the collision: virtual (do nothing) or real\n            if SigV / SigTmax[iGroup[iNeutron]] >= np.random.rand():  # virtual collision\n\n                virtualCollision = True\n\n            else:  # real collision\n\n                virtualCollision = False\n\n                # Sample type of the collision: scattering or absorption\n                if SigS_sum / SigT >= np.random.rand():  # isotropic scattering\n\n                    # Score scatterings with account for weight divided by the\n                    # total scattering cross section\n                    detectS[iGroup[iNeutron]] += weight[iNeutron] / SigS_sum\n\n                    # Sample the energy group of the secondary neutron\n                    iGroup[iNeutron] = np.argmax(np.cumsum(SigS) / SigS_sum >= np.random.rand())\n\n                else:  # absorption\n\n                    absorbed = True\n\n                    # Neutron is converted to the new fission neutron with\n                    # t ...

# %% [markdown]
# ### The main iteration loop (with functions)

# %%
"""# Start stopwatch
start_time = t.time()  # Placeholder for stopwatch functionality in Python

#--------------------------------------------------------------------------
# Number of source neutrons
numNeutrons_born = 100      # INPUT

# Number of inactive source cycles to skip before starting k-eff accumulation
numCycles_inactive = 100    # INPUT

# Number of active source cycles for k-eff accumulation
numCycles_active = 100     # INPUT

# Size of the square unit cell
pitch = 3.6  # cm           # INPUT

# Define fuel and coolant regions
fuelLeft, fuelRight = 0.9, 2.7  # INPUT
coolLeft, coolRight = 0.7, 2.9  # INPUT
#--------------------------------------------------------------------------
# Path to macroscopic cross section data:
# (Assuming the corresponding data files are available and accessible)
#macro_xs_path = '..//02.Macro.XS.421g'

# Fill the structures fuel, clad, and cool with the cross-section data
fuel = hdf2dict('macro421_UO2_03__900K.h5')  # INPUT
print(f"File 'macro421_UO2_03__900K.h5' has been read in.")
clad = hdf2dict('macro421_Zry__600K.h5')     # INPUT
print(f"File 'macro421_Zry__600K.h5' has been read in.")
cool  = hdf2dict('macro421_H2OB__600K.h5')   # INPUT
print(f"File 'macro421_H2OB__600K.h5' has been read in.")

# Define the majorant: the maximum total cross-section vector
# This part just looks at all the three different vectors and creates a new
# vector that picks out the largest value for every index from each of the 
# three vectros. Althought there are some rounding differences.
SigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)

# Number of energy groups
ng = fuel['ng']

#--------------------------------------------------------------------------
# Detectors
detectS = np.zeros(ng)

#--------------------------------------------------------------------------
# Four main vectors describing the neutrons in a batch
x = np.zeros(numNeutrons_born * 2)
y = np.zeros(numNeutrons_born * 2)
weight = np.ones(numNeutrons_born * 2)
iGroup = np.ones(numNeutrons_born * 2, dtype=int)

#--------------------------------------------------------------------------
# Neutrons are assumed born randomly distributed in the cell with weight 1
# with sampled fission energy spectrum
numNeutrons = numNeutrons_born
for iNeutron in range(numNeutrons):
    x[iNeutron] = np.random.rand() * pitch
    y[iNeutron] = np.random.rand() * pitch
    weight[iNeutron] = 1
    # Sample the neutron energy group
    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())
#print(iGroup)

#--------------------------------------------------------------------------
# Prepare vectors for keff and standard deviation of keff
keff_expected = np.ones(numCycles_active)
sigma_keff = np.zeros(numCycles_active)
keff_active_cycle = np.ones(numCycles_active)
virtualCollision = False

# Main (power) iteration loop
for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

    # Normalize the weights of the neutrons to make the total weight equal to
    # numNeutrons_born (equivalent to division by keff_cycle)
    #weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
    weight = (weight / np.sum(weight)) * numNeutrons_born
    weight0 = weight.copy()
    #print("weight0 = ", weight0)
    #----------------------------------------------------------------------
    # Loop over neutrons
    for iNeutron in range(numNeutrons):

        absorbed = False

        #------------------------------------------------------------------
        # Neutron random walk cycle: from emission to absorption

        while not absorbed:
            #print("Neutron was absorbed!")
            # Sample free path length according to the Woodcock method
            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print("freePath = ", freePath)

            if not virtualCollision:
                #print("Collision was virtual!")
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                dirX, dirY = sample_direction()
            # Fly
            x, y = move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)

            # Find the total and scattering cross sections                    
            SigA, SigS, SigP = calculate_cross_sections(fuelLeft, fuelRight, coolLeft, coolRight, x, iNeutron, iGroup, fuel, cool, clad)
            
            # Sample the type of the collision: virtual (do nothing) or real
            absorbed, virtualCollision, iGroup, weight, detectS = perform_collision(virtualCollision, absorbed, SigS, SigA, SigP, 
                                                                                SigTmax, iGroup, iNeutron, detectS, weight, fuel["chi"])
        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    weight = russian_roulette(weight, weight0)

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons
    x, y, iGroup, weight, numNeutrons = update_indices(x, y, iGroup, weight)

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    weight, numNeutrons, x, y, iGroup = split_neutrons(weight, numNeutrons, x, y, iGroup)

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    calculate_keff_cycle(iCycle, numCycles_inactive, numCycles_active, weight, weight0, numNeutrons, keff_active_cycle, keff_expected, sigma_keff)

    # End of main (power) iteration"""
# Out:
# '# Start stopwatch\nstart_time = t.time()  # Placeholder for stopwatch functionality in Python\n\n#--------------------------------------------------------------------------\n# Number of source neutrons\nnumNeutrons_born = 100      # INPUT\n\n# Number of inactive source cycles to skip before starting k-eff accumulation\nnumCycles_inactive = 100    # INPUT\n\n# Number of active source cycles for k-eff accumulation\nnumCycles_active = 100     # INPUT\n\n# Size of the square unit cell\npitch = 3.6  # cm           # INPUT\n\n# Define fuel and coolant regions\nfuelLeft, fuelRight = 0.9, 2.7  # INPUT\ncoolLeft, coolRight = 0.7, 2.9  # INPUT\n#--------------------------------------------------------------------------\n# Path to macroscopic cross section data:\n# (Assuming the corresponding data files are available and accessible)\n#macro_xs_path = \'..//02.Macro.XS.421g\'\n\n# Fill the structures fuel, clad, and cool with the cross-section data\nfuel = hdf2dict(\'macro421_UO2_03__900K.h5\')  # INPUT\nprint(f"File \'macro421_UO2_03__900K.h5\' has been read in.")\nclad = hdf2dict(\'macro421_Zry__600K.h5\')     # INPUT\nprint(f"File \'macro421_Zry__600K.h5\' has been read in.")\ncool  = hdf2dict(\'macro421_H2OB__600K.h5\')   # INPUT\nprint(f"File \'macro421_H2OB__600K.h5\' has been read in.")\n\n# Define the majorant: the maximum total cross-section vector\n# This part just looks at all the three different vectors and creates a new\n# vector that picks out the largest value for every index from each of the \n# three vectros. Althought there are some rounding differences.\nSigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)\n\n# Number of energy groups\nng = fuel[\'ng\']\n\n#--------------------------------------------------------------------------\n# Detectors\ndetectS = np.zeros(ng)\n\n#--------------------------------------------------------------------------\n# Four main vectors describing the neutrons in a batch\nx = np.zeros(numNeutrons_born * 2)\ny = np.zeros(numNeutrons_born * 2)\nweight = np.ones(numNeutrons_born * 2)\niGroup = np.ones(numNeutrons_born * 2, dtype=int)\n\n#--------------------------------------------------------------------------\n# Neutrons are assumed born randomly distributed in the cell with weight 1\n# with sampled fission energy spectrum\nnumNeutrons = numNeutrons_born\nfor iNeutron in range(numNeutrons):\n    x[iNeutron] = np.random.rand() * pitch\n    y[iNeutron] = np.random.rand() * pitch\n    weight[iNeutron] = 1\n    # Sample the neutron energy group\n    iGroup[iNeutron] = np.argmax(np.cumsum(fuel[\'chi\']) >= np.random.rand())\n#print(iGroup)\n\n#--------------------------------------------------------------------------\n# Prepare vectors for keff and standard deviation of keff\nkeff_expected = np.ones(numCycles_active)\nsigma_keff = np.zeros(numCycles_active)\nkeff_active_cycle = np.ones(numCycles_active)\nvirtualCollision = False\n\n# Main (power) iteration loop\nfor iCycle in range(1, numCycles_inactive + numCycles_active + 1):\n\n    # Normalize the weights of the neutrons to make the total weight equal to\n    # numNeutrons_born (equivalent to division by keff_cycle)\n    #weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born\n    weight = (weight / np.sum(weight)) * numNeutrons_born\n    weight0 = weight.copy()\n    #print("weight0 = ", weight0)\n    #----------------------------------------------------------------------\n    # Loop over neutrons\n    for iNeutron in range(numNeutrons):\n\n        absorbed = False\n\n        #------------------------------------------------------------------\n        # Neutron random walk cycle: from emission to absorption\n\n        while not absorbed:\n            #print("Neutron was absorbed!")\n            # Sample free path length according to the Woodcock method\n            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]\n            #print("freePath = ", freePath)\n\n            if not  ...

# %%
# Start stopwatch
start_time = t.time()  # Placeholder for stopwatch functionality in Python

#--------------------------------------------------------------------------
# Number of source neutrons
numNeutrons_born = 100      # INPUT

# Number of inactive source cycles to skip before starting k-eff accumulation
numCycles_inactive = 100    # INPUT

# Number of active source cycles for k-eff accumulation
numCycles_active = 100     # INPUT

# Size of the square unit cell
pitch = 3.6  # cm           # INPUT

# Define fuel and coolant regions
fuelLeft, fuelRight = 0.9, 2.7  # INPUT
coolLeft, coolRight = 0.7, 2.9  # INPUT
#--------------------------------------------------------------------------
# Path to macroscopic cross section data:
# (Assuming the corresponding data files are available and accessible)
#macro_xs_path = '..//02.Macro.XS.421g'

# Fill the structures fuel, clad, and cool with the cross-section data
fuel = hdf2dict('macro421_UO2_03__900K.h5')  # INPUT
print(f"File 'macro421_UO2_03__900K.h5' has been read in.")
clad = hdf2dict('macro421_Zry__600K.h5')     # INPUT
print(f"File 'macro421_Zry__600K.h5' has been read in.")
cool  = hdf2dict('macro421_H2OB__600K.h5')   # INPUT
print(f"File 'macro421_H2OB__600K.h5' has been read in.")

# Define the majorant: the maximum total cross-section vector
# This part just looks at all the three different vectors and creates a new
# vector that picks out the largest value for every index from each of the 
# three vectros. Althought there are some rounding differences.
SigTmax = np.max(np.vstack((fuel["SigT"], clad["SigT"], cool["SigT"])), axis=0)

# Number of energy groups
ng = fuel['ng']

#--------------------------------------------------------------------------
# Detectors
detectS = np.zeros(ng)

#--------------------------------------------------------------------------
# Four main vectors describing the neutrons in a batch
x = np.zeros(numNeutrons_born * 2)
y = np.zeros(numNeutrons_born * 2)
weight = np.ones(numNeutrons_born * 2)
iGroup = np.ones(numNeutrons_born * 2, dtype=np.int64)

#--------------------------------------------------------------------------
# Neutrons are assumed born randomly distributed in the cell with weight 1
# with sampled fission energy spectrum
numNeutrons = numNeutrons_born
for iNeutron in range(numNeutrons):
    x[iNeutron] = np.random.rand() * pitch
    y[iNeutron] = np.random.rand() * pitch
    weight[iNeutron] = 1
    # Sample the neutron energy group
    iGroup[iNeutron] = np.argmax(np.cumsum(fuel['chi']) >= np.random.rand())
#print(iGroup)

#--------------------------------------------------------------------------
# Prepare vectors for keff and standard deviation of keff
keff_expected = np.ones(numCycles_active)
sigma_keff = np.zeros(numCycles_active)
keff_active_cycle = np.ones(numCycles_active)
virtualCollision = False

# Main (power) iteration loop
for iCycle in range(1, numCycles_inactive + numCycles_active + 1):

    # Normalize the weights of the neutrons to make the total weight equal to
    # numNeutrons_born (equivalent to division by keff_cycle)
    #weight = (weight / np.sum(weight, axis=0, keepdims=True)) * numNeutrons_born
    weight = (weight / np.sum(weight)) * numNeutrons_born
    weight0 = weight.copy()
    #print("weight0 = ", weight0)
    #----------------------------------------------------------------------
    # Loop over neutrons
    for iNeutron in range(numNeutrons):

        absorbed = False

        #------------------------------------------------------------------
        # Neutron random walk cycle: from emission to absorption

        while not absorbed:
            #print("Neutron was absorbed!")
            # Sample free path length according to the Woodcock method
            freePath = -np.log(np.random.rand()) / SigTmax[iGroup[iNeutron]]
            #print("freePath = ", freePath)

            if not virtualCollision:
                #print("Collision was virtual!")
                # Sample the direction of neutron flight assuming both
                # fission and scattering are isotropic in the lab (a strong
                # assumption!)
                dirX, dirY = mp.sample_direction()
            # Fly
            x, y = mp.move_neutron(x, y, iNeutron, pitch, freePath, dirX, dirY)

            # Find the total and scattering cross sections                    
            SigA, SigS, SigP = mp.calculate_cross_sections(fuelLeft, fuelRight, coolLeft, coolRight, x, iNeutron, iGroup, fuel, cool, clad)
            
            # Sample the type of the collision: virtual (do nothing) or real
            absorbed, virtualCollision, iGroup, weight, detectS = mp.perform_collision(virtualCollision, absorbed, SigS, SigA, SigP, 
                                                                                SigTmax, iGroup, iNeutron, detectS, weight, fuel["chi"])
        # End of neutron random walk cycle: from emission to absorption
    # End of loop over neutrons
    #-------------------------------------------------------------------------------------------
    # Russian roulette
    weight = mp.russian_roulette(weight, weight0)

    #-------------------------------------------------------------------------------------------
    # Clean up absorbed or killed neutrons
    x, y, iGroup, weight, numNeutrons = mp.update_indices(x, y, iGroup, weight)

    #-------------------------------------------------------------------------------------------
    # Split too "heavy" neutrons
    weight, numNeutrons, x, y, iGroup = mp.split_neutrons(weight, numNeutrons, x, y, iGroup)

    #-------------------------------------------------------------------------------------------
    # k-eff in a cycle equals the total weight of the new generation over
    # the total weight of the old generation (the old generation weight =
    # numNeutronsBorn)
    mp.calculate_keff_cycle(iCycle, numCycles_inactive, numCycles_active, weight, weight0, numNeutrons, keff_active_cycle, keff_expected, sigma_keff)

    # End of main (power) iteration
# Out:
# File 'macro421_UO2_03__900K.h5' has been read in.
# File 'macro421_Zry__600K.h5' has been read in.
# File 'macro421_H2OB__600K.h5' has been read in.
# Inactive cycle =   1/100; k-eff cycle = 0.99472; numNeutrons = 165
# Inactive cycle =   2/100; k-eff cycle = 1.00491; numNeutrons = 109
# Inactive cycle =   3/100; k-eff cycle = 0.94451; numNeutrons =  98
# Inactive cycle =   4/100; k-eff cycle = 1.06944; numNeutrons = 109
# Inactive cycle =   5/100; k-eff cycle = 1.12338; numNeutrons = 122
# Inactive cycle =   6/100; k-eff cycle = 1.06937; numNeutrons = 118
# Inactive cycle =   7/100; k-eff cycle = 1.15271; numNeutrons = 123
# Inactive cycle =   8/100; k-eff cycle = 0.96731; numNeutrons =  99
# Inactive cycle =   9/100; k-eff cycle = 1.11472; numNeutrons = 109
# Inactive cycle =  10/100; k-eff cycle = 1.03897; numNeutrons = 104
# Inactive cycle =  11/100; k-eff cycle = 1.03990; numNeutrons = 110
# Inactive cycle =  12/100; k-eff cycle = 1.07545; numNeutrons = 113
# Inactive cycle =  13/100; k-eff cycle = 1.06376; numNeutrons = 105
# Inactive cycle =  14/100; k-eff cycle = 1.12608; numNeutrons = 123
# Inactive cycle =  15/100; k-eff cycle = 1.03614; numNeutrons = 106
# Inactive cycle =  16/100; k-eff cycle = 0.98811; numNeutrons = 102
# Inactive cycle =  17/100; k-eff cycle = 0.91077; numNeutrons =  94
# Inactive cycle =  18/100; k-eff cycle = 0.94121; numNeutrons =  98
# Inactive cycle =  19/100; k-eff cycle = 0.86444; numNeutrons =  86
# Inactive cycle =  20/100; k-eff cycle = 1.05344; numNeutrons = 105
# Inactive cycle =  21/100; k-eff cycle = 0.82953; numNeutrons =  83
# Inactive cycle =  22/100; k-eff cycle = 0.94154; numNeutrons =  95
# Inactive cycle =  23/100; k-eff cycle = 1.10796; numNeutrons = 110
# Inactive cycle =  24/100; k-eff cycle = 1.11007; numNeutrons = 111
# Inactive cycle =  25/100; k-eff cycle = 0.90125; numNeutrons =  91
# Inactive cycle =  26/100; k-eff cycle = 0.98139; numNeutrons =  99
# Inactive cycle =  27/100; k-eff cycle = 0.94995; numNeutrons = 104
# Inactive cycle =  28/100; k-eff cycle = 0.93252; numNeutrons =  95
# Inactive cycle =  29/100; k-eff cycle = 1.09830; numNeutrons = 120
# Inactive cycle =  30/100; k-eff cycle = 0.95387; numNeutrons = 105
# Inactive cycle =  31/100; k-eff cycle = 1.05680; numNeutrons = 108
# Inactive cycle =  32/100; k-eff cycle = 0.87757; numNeutrons =  93
# Inactive cycle =  33/100; k-eff cycle = 1.01884; numNeutrons = 106
# Inactive cycle =  34/100; k-eff cycle = 1.02702; numNeutrons = 109
# Inactive cycle =  35/100; k-eff cycle = 1.03716; numNeutrons = 103
# Inactive cycle =  36/100; k-eff cycle = 1.11987; numNeutrons = 118
# Inactive cycle =  37/100; k-eff cycle = 1.10429; numNeutrons = 120
# Inactive cycle =  38/100; k-eff cycle = 1.09868; numNeutrons = 119
# Inactive cycle =  39/100; k-eff cycle = 0.95417; numNeutrons = 105
# Inactive cycle =  40/100; k-eff cycle = 0.99247; numNeutrons = 103
# Inactive cycle =  41/100; k-eff cycle = 0.98093; numNeutrons = 103
# Inactive cycle =  42/100; k-eff cycle = 1.15420; numNeutrons = 121
# Inactive cycle =  43/100; k-eff cycle = 1.13505; numNeutrons = 120
# Inactive cycle =  44/100; k-eff cycle = 1.13247; numNeutrons = 118
# Inactive cycle =  45/100; k-eff cycle = 0.94343; numNeutrons = 101
# Inactive cycle =  46/100; k-eff cycle = 1.05491; numNeutrons = 104
# Inactive cycle =  47/100; k-eff cycle = 1.09890; numNeutrons = 110
# Inactive cycle =  48/100; k-eff cycle = 1.09542; numNeutrons = 114
# Inactive cycle =  49/100; k-eff cycle = 1.08448; numNeutrons = 111
# Inactive cycle =  50/100; k-eff cycle = 0.87379; numNeutrons =  93
# Inactive cycle =  51/100; k-eff cycle = 1.05178; numNeutrons = 106
# Inactive cycle =  52/100; k-eff cycle = 0.94614; numNeutrons =  95
# Inactive cycle =  53/100; k-eff cycle = 0.99985; numNeutrons = 102
# Inactive cycle =  54/100; k-eff cycle = 1.12616; numNeutrons = 111
# Inactive cycle =  55/100; k-eff cycle = 0.93726; numNeutrons =  93
# Inactive cycle =  56/100; k-eff cycle = 0.92747; numNeutrons =  93
# Inactive cycle =  57/100; k-eff cycle = 0.97492; numNeutrons = 101
# Inactive cycle =  58/100; k-eff cycle = 0.95247; numNeutrons =  95
# Inactive cycle =  59/100; k-eff cycle = 0.97677; numNeutrons =  95
# Inactive cycle =  60/100; k-eff cycle = 0.92014; numNeutrons =  88
# Inactive cycle =  61/100; k-eff cycle = 1.05600; numNeutrons = 104
# Inactive cycle =  62/100; k-eff cycle = 1.07537; numNeutrons = 113
# Inactive cycle =  63/100; k-eff cycle = 0.94237; numNeutrons = 100
# Inactive cycle =  64/100; k-eff cycle = 1.10992; numNeutrons = 115
# Inactive cycle =  65/100; k-eff cycle = 1.05293; numNeutrons = 106
# Inactive cycle =  66/100; k-eff cycle = 1.06287; numNeutrons = 109
# Inactive cycle =  67/100; k-eff cycle = 0.89059; numNeutrons =  91
# Inactive cycle =  68/100; k-eff cycle = 1.05245; numNeutrons = 102
# Inactive cycle =  69/100; k-eff cycle = 1.01208; numNeutrons = 101
# Inactive cycle =  70/100; k-eff cycle = 1.00947; numNeutrons = 100
# Inactive cycle =  71/100; k-eff cycle = 1.00120; numNeutrons =  99
# Inactive cycle =  72/100; k-eff cycle = 0.90889; numNeutrons =  95
# Inactive cycle =  73/100; k-eff cycle = 0.95353; numNeutrons =  98
# Inactive cycle =  74/100; k-eff cycle = 1.07267; numNeutrons = 111
# Inactive cycle =  75/100; k-eff cycle = 0.89815; numNeutrons =  93
# Inactive cycle =  76/100; k-eff cycle = 1.09009; numNeutrons = 112
# Inactive cycle =  77/100; k-eff cycle = 1.05862; numNeutrons = 111
# Inactive cycle =  78/100; k-eff cycle = 1.15360; numNeutrons = 118
# Inactive cycle =  79/100; k-eff cycle = 0.91844; numNeutrons =  96
# Inactive cycle =  80/100; k-eff cycle = 0.89060; numNeutrons =  91
# Inactive cycle =  81/100; k-eff cycle = 1.09075; numNeutrons = 111
# Inactive cycle =  82/100; k-eff cycle = 1.04459; numNeutrons = 112
# Inactive cycle =  83/100; k-eff cycle = 1.12856; numNeutrons = 113
# Inactive cycle =  84/100; k-eff cycle = 1.17680; numNeutrons = 121
# Inactive cycle =  85/100; k-eff cycle = 1.00446; numNeutrons = 105
# Inactive cycle =  86/100; k-eff cycle = 1.09117; numNeutrons = 113
# Inactive cycle =  87/100; k-eff cycle = 1.00938; numNeutrons = 102
# Inactive cycle =  88/100; k-eff cycle = 0.96982; numNeutrons = 100
# Inactive cycle =  89/100; k-eff cycle = 0.94721; numNeutrons = 100
# Inactive cycle =  90/100; k-eff cycle = 0.96257; numNeutrons =  93
# Inactive cycle =  91/100; k-eff cycle = 1.12820; numNeutrons = 112
# Inactive cycle =  92/100; k-eff cycle = 1.10427; numNeutrons = 113
# Inactive cycle =  93/100; k-eff cycle = 1.17536; numNeutrons = 120
# Inactive cycle =  94/100; k-eff cycle = 1.06843; numNeutrons = 111
# Inactive cycle =  95/100; k-eff cycle = 0.97917; numNeutrons = 108
# Inactive cycle =  96/100; k-eff cycle = 0.92420; numNeutrons =  98
# Inactive cycle =  97/100; k-eff cycle = 0.99478; numNeutrons = 106
# Inactive cycle =  98/100; k-eff cycle = 0.87755; numNeutrons =  86
# Inactive cycle =  99/100; k-eff cycle = 1.00093; numNeutrons =  99
# Inactive cycle = 100/100; k-eff cycle = 1.07024; numNeutrons = 105
# Active cycle =   1/100; k-eff cycle = 1.03099; numNeutrons = 109; k-eff expected = 1.03099; sigma = 0.00000
# Active cycle =   2/100; k-eff cycle = 0.94856; numNeutrons =  94; k-eff expected = 0.98977; sigma = 0.04121
# Active cycle =   3/100; k-eff cycle = 1.04489; numNeutrons = 106; k-eff expected = 1.00815; sigma = 0.03006
# Active cycle =   4/100; k-eff cycle = 1.01936; numNeutrons = 108; k-eff expected = 1.01095; sigma = 0.02144
# Active cycle =   5/100; k-eff cycle = 1.07534; numNeutrons = 111; k-eff expected = 1.02383; sigma = 0.02102
# Active cycle =   6/100; k-eff cycle = 1.04298; numNeutrons = 112; k-eff expected = 1.02702; sigma = 0.01745
# Active cycle =   7/100; k-eff cycle = 0.81166; numNeutrons =  87; k-eff expected = 0.99626; sigma = 0.03412
# Active cycle =   8/100; k-eff cycle = 1.09897; numNeutrons = 107; k-eff expected = 1.00909; sigma = 0.03222
# Active cycle =   9/100; k-eff cycle = 1.05862; numNeutrons = 107; k-eff expected = 1.01460; sigma = 0.02894
# Active cycle =  10/100; k-eff cycle = 0.97742; numNeutrons = 101; k-eff expected = 1.01088; sigma = 0.02615
# Active cycle =  11/100; k-eff cycle = 1.05171; numNeutrons = 111; k-eff expected = 1.01459; sigma = 0.02394
# Active cycle =  12/100; k-eff cycle = 1.04153; numNeutrons = 114; k-eff expected = 1.01684; sigma = 0.02197
# Active cycle =  13/100; k-eff cycle = 0.92980; numNeutrons =  96; k-eff expected = 1.01014; sigma = 0.02129
# Active cycle =  14/100; k-eff cycle = 0.87413; numNeutrons =  88; k-eff expected = 1.00043; sigma = 0.02198
# Active cycle =  15/100; k-eff cycle = 0.95100; numNeutrons =  98; k-eff expected = 0.99713; sigma = 0.02072
# Active cycle =  16/100; k-eff cycle = 0.92148; numNeutrons =  95; k-eff expected = 0.99240; sigma = 0.01995
# Active cycle =  17/100; k-eff cycle = 0.95510; numNeutrons = 101; k-eff expected = 0.99021; sigma = 0.01887
# Active cycle =  18/100; k-eff cycle = 1.09020; numNeutrons = 110; k-eff expected = 0.99576; sigma = 0.01864
# Active cycle =  19/100; k-eff cycle = 1.04498; numNeutrons = 112; k-eff expected = 0.99835; sigma = 0.01782
# Active cycle =  20/100; k-eff cycle = 1.03787; numNeutrons = 108; k-eff expected = 1.00033; sigma = 0.01702
# Active cycle =  21/100; k-eff cycle = 0.96891; numNeutrons = 105; k-eff expected = 0.99883; sigma = 0.01626
# Active cycle =  22/100; k-eff cycle = 1.06361; numNeutrons = 113; k-eff expected = 1.00178; sigma = 0.01578
# Active cycle =  23/100; k-eff cycle = 0.90834; numNeutrons = 101; k-eff expected = 0.99772; sigma = 0.01561
# Active cycle =  24/100; k-eff cycle = 1.08277; numNeutrons = 112; k-eff expected = 1.00126; sigma = 0.01536
# Active cycle =  25/100; k-eff cycle = 1.10638; numNeutrons = 116; k-eff expected = 1.00546; sigma = 0.01532
# Active cycle =  26/100; k-eff cycle = 1.02137; numNeutrons = 107; k-eff expected = 1.00608; sigma = 0.01474
# Active cycle =  27/100; k-eff cycle = 1.05762; numNeutrons = 105; k-eff expected = 1.00799; sigma = 0.01431
# Active cycle =  28/100; k-eff cycle = 1.06165; numNeutrons = 110; k-eff expected = 1.00990; sigma = 0.01392
# Active cycle =  29/100; k-eff cycle = 1.06161; numNeutrons = 112; k-eff expected = 1.01168; sigma = 0.01355
# Active cycle =  30/100; k-eff cycle = 1.08172; numNeutrons = 114; k-eff expected = 1.01402; sigma = 0.01330
# Active cycle =  31/100; k-eff cycle = 1.11171; numNeutrons = 117; k-eff expected = 1.01717; sigma = 0.01324
# Active cycle =  32/100; k-eff cycle = 1.05827; numNeutrons = 109; k-eff expected = 1.01845; sigma = 0.01288
# Active cycle =  33/100; k-eff cycle = 0.88760; numNeutrons = 100; k-eff expected = 1.01449; sigma = 0.01310
# Active cycle =  34/100; k-eff cycle = 0.99251; numNeutrons = 105; k-eff expected = 1.01384; sigma = 0.01273
# Active cycle =  35/100; k-eff cycle = 1.11320; numNeutrons = 119; k-eff expected = 1.01668; sigma = 0.01268
# Active cycle =  36/100; k-eff cycle = 1.13294; numNeutrons = 121; k-eff expected = 1.01991; sigma = 0.01274
# Active cycle =  37/100; k-eff cycle = 0.93342; numNeutrons =  98; k-eff expected = 1.01757; sigma = 0.01261
# Active cycle =  38/100; k-eff cycle = 1.10310; numNeutrons = 110; k-eff expected = 1.01982; sigma = 0.01248
# Active cycle =  39/100; k-eff cycle = 1.02252; numNeutrons = 107; k-eff expected = 1.01989; sigma = 0.01215
# Active cycle =  40/100; k-eff cycle = 1.14524; numNeutrons = 122; k-eff expected = 1.02303; sigma = 0.01225
# Active cycle =  41/100; k-eff cycle = 1.04709; numNeutrons = 112; k-eff expected = 1.02361; sigma = 0.01196
# Active cycle =  42/100; k-eff cycle = 1.14162; numNeutrons = 119; k-eff expected = 1.02642; sigma = 0.01201
# Active cycle =  43/100; k-eff cycle = 0.93581; numNeutrons = 100; k-eff expected = 1.02432; sigma = 0.01191
# Active cycle =  44/100; k-eff cycle = 1.01754; numNeutrons = 108; k-eff expected = 1.02416; sigma = 0.01164
# Active cycle =  45/100; k-eff cycle = 0.85287; numNeutrons =  93; k-eff expected = 1.02036; sigma = 0.01200
# Active cycle =  46/100; k-eff cycle = 0.77106; numNeutrons =  75; k-eff expected = 1.01494; sigma = 0.01293
# Active cycle =  47/100; k-eff cycle = 1.10529; numNeutrons = 113; k-eff expected = 1.01686; sigma = 0.01279
# Active cycle =  48/100; k-eff cycle = 0.99520; numNeutrons = 103; k-eff expected = 1.01641; sigma = 0.01253
# Active cycle =  49/100; k-eff cycle = 1.06010; numNeutrons = 106; k-eff expected = 1.01730; sigma = 0.01231
# Active cycle =  50/100; k-eff cycle = 0.97584; numNeutrons = 101; k-eff expected = 1.01647; sigma = 0.01209
# Active cycle =  51/100; k-eff cycle = 1.07720; numNeutrons = 109; k-eff expected = 1.01766; sigma = 0.01191
# Active cycle =  52/100; k-eff cycle = 1.05755; numNeutrons = 108; k-eff expected = 1.01843; sigma = 0.01170
# Active cycle =  53/100; k-eff cycle = 1.08484; numNeutrons = 110; k-eff expected = 1.01968; sigma = 0.01155
# Active cycle =  54/100; k-eff cycle = 1.10406; numNeutrons = 116; k-eff expected = 1.02124; sigma = 0.01144
# Active cycle =  55/100; k-eff cycle = 0.96546; numNeutrons =  97; k-eff expected = 1.02023; sigma = 0.01127
# Active cycle =  56/100; k-eff cycle = 1.01316; numNeutrons = 106; k-eff expected = 1.02010; sigma = 0.01107
# Active cycle =  57/100; k-eff cycle = 1.12946; numNeutrons = 114; k-eff expected = 1.02202; sigma = 0.01104
# Active cycle =  58/100; k-eff cycle = 1.09596; numNeutrons = 118; k-eff expected = 1.02330; sigma = 0.01093
# Active cycle =  59/100; k-eff cycle = 1.09487; numNeutrons = 116; k-eff expected = 1.02451; sigma = 0.01081
# Active cycle =  60/100; k-eff cycle = 0.95909; numNeutrons = 102; k-eff expected = 1.02342; sigma = 0.01068
# Active cycle =  61/100; k-eff cycle = 1.05444; numNeutrons = 108; k-eff expected = 1.02393; sigma = 0.01052
# Active cycle =  62/100; k-eff cycle = 0.94163; numNeutrons =  97; k-eff expected = 1.02260; sigma = 0.01043
# Active cycle =  63/100; k-eff cycle = 0.86461; numNeutrons =  89; k-eff expected = 1.02009; sigma = 0.01057
# Active cycle =  64/100; k-eff cycle = 0.78985; numNeutrons =  79; k-eff expected = 1.01649; sigma = 0.01100
# Active cycle =  65/100; k-eff cycle = 1.02147; numNeutrons = 102; k-eff expected = 1.01657; sigma = 0.01083
# Active cycle =  66/100; k-eff cycle = 0.93188; numNeutrons =  96; k-eff expected = 1.01529; sigma = 0.01075
# Active cycle =  67/100; k-eff cycle = 1.02823; numNeutrons = 106; k-eff expected = 1.01548; sigma = 0.01059
# Active cycle =  68/100; k-eff cycle = 1.06018; numNeutrons = 113; k-eff expected = 1.01614; sigma = 0.01045
# Active cycle =  69/100; k-eff cycle = 0.94906; numNeutrons =  93; k-eff expected = 1.01517; sigma = 0.01034
# Active cycle =  70/100; k-eff cycle = 1.08906; numNeutrons = 109; k-eff expected = 1.01622; sigma = 0.01025
# Active cycle =  71/100; k-eff cycle = 0.99705; numNeutrons = 101; k-eff expected = 1.01595; sigma = 0.01011
# Active cycle =  72/100; k-eff cycle = 1.04361; numNeutrons = 103; k-eff expected = 1.01634; sigma = 0.00997
# Active cycle =  73/100; k-eff cycle = 1.03482; numNeutrons = 104; k-eff expected = 1.01659; sigma = 0.00984
# Active cycle =  74/100; k-eff cycle = 1.07148; numNeutrons = 105; k-eff expected = 1.01733; sigma = 0.00973
# Active cycle =  75/100; k-eff cycle = 1.07397; numNeutrons = 108; k-eff expected = 1.01809; sigma = 0.00963
# Active cycle =  76/100; k-eff cycle = 0.98712; numNeutrons = 104; k-eff expected = 1.01768; sigma = 0.00951
# Active cycle =  77/100; k-eff cycle = 1.00677; numNeutrons = 105; k-eff expected = 1.01754; sigma = 0.00939
# Active cycle =  78/100; k-eff cycle = 0.99463; numNeutrons = 103; k-eff expected = 1.01724; sigma = 0.00927
# Active cycle =  79/100; k-eff cycle = 0.99004; numNeutrons = 103; k-eff expected = 1.01690; sigma = 0.00916
# Active cycle =  80/100; k-eff cycle = 1.11655; numNeutrons = 123; k-eff expected = 1.01814; sigma = 0.00913
# Active cycle =  81/100; k-eff cycle = 1.03616; numNeutrons = 116; k-eff expected = 1.01837; sigma = 0.00902
# Active cycle =  82/100; k-eff cycle = 0.96698; numNeutrons = 101; k-eff expected = 1.01774; sigma = 0.00893
# Active cycle =  83/100; k-eff cycle = 0.99460; numNeutrons =  99; k-eff expected = 1.01746; sigma = 0.00883
# Active cycle =  84/100; k-eff cycle = 1.09130; numNeutrons = 119; k-eff expected = 1.01834; sigma = 0.00877
# Active cycle =  85/100; k-eff cycle = 1.07712; numNeutrons = 114; k-eff expected = 1.01903; sigma = 0.00869
# Active cycle =  86/100; k-eff cycle = 0.95937; numNeutrons =  95; k-eff expected = 1.01834; sigma = 0.00862
# Active cycle =  87/100; k-eff cycle = 0.95068; numNeutrons =  94; k-eff expected = 1.01756; sigma = 0.00855
# Active cycle =  88/100; k-eff cycle = 0.95651; numNeutrons =  96; k-eff expected = 1.01687; sigma = 0.00848
# Active cycle =  89/100; k-eff cycle = 0.97765; numNeutrons =  99; k-eff expected = 1.01643; sigma = 0.00840
# Active cycle =  90/100; k-eff cycle = 0.95339; numNeutrons = 100; k-eff expected = 1.01573; sigma = 0.00833
# Active cycle =  91/100; k-eff cycle = 0.99218; numNeutrons =  98; k-eff expected = 1.01547; sigma = 0.00825
# Active cycle =  92/100; k-eff cycle = 1.01009; numNeutrons = 102; k-eff expected = 1.01541; sigma = 0.00816
# Active cycle =  93/100; k-eff cycle = 1.03081; numNeutrons = 105; k-eff expected = 1.01557; sigma = 0.00807
# Active cycle =  94/100; k-eff cycle = 1.09621; numNeutrons = 108; k-eff expected = 1.01643; sigma = 0.00803
# Active cycle =  95/100; k-eff cycle = 0.99719; numNeutrons = 103; k-eff expected = 1.01623; sigma = 0.00795
# Active cycle =  96/100; k-eff cycle = 1.10146; numNeutrons = 113; k-eff expected = 1.01712; sigma = 0.00791
# Active cycle =  97/100; k-eff cycle = 0.99793; numNeutrons = 111; k-eff expected = 1.01692; sigma = 0.00783
# Active cycle =  98/100; k-eff cycle = 1.02607; numNeutrons = 104; k-eff expected = 1.01701; sigma = 0.00775
# Active cycle =  99/100; k-eff cycle = 1.02140; numNeutrons = 108; k-eff expected = 1.01706; sigma = 0.00768
# Active cycle = 100/100; k-eff cycle = 0.90012; numNeutrons =  91; k-eff expected = 1.01589; sigma = 0.00769

# %%
fuel.keys()
# Out:
# dict_keys(['SigC', 'SigF', 'SigL', 'SigP', 'SigT', 'aw', 'chi', 'den', 'eg', 'fissile', 'isoName', 'ng', 'numDen', 'sig0', 'sig2_G', 'sigS_G', 'temp'])

# %%
from numba import njit
import numpy as np

@njit
def process_fuel_data(fuel_data: tuple) -> np.ndarray:
    sigC, sigF, sigL, chi = fuel_data

    # Perform computations using the fuel data
    # Example: Compute the total cross section
    sigT = sigC + sigF + sigL

    # Return the computed value
    return sigT

# Test data
testdata = (
    np.array([0.5, 0.3, 0.2]),
    np.array([0.1, 0.2, 0.3]),
    np.array([0.4, 0.2, 0.1]),
    np.array([1.0, 0.8, 0.5])
)

# Call the function
result = process_fuel_data(testdata)
print(type(result))
# Out:
# <class 'numpy.ndarray'>

# %%
type(numNeutrons)
# Out:
# int
